# %%
# %load_ext autoreload
# %autoreload 2

# In a Jupyter Notebook cell
import logging
from brancharchitect.io import read_newick


# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
trees = read_newick("./data/alltrees_treees_cutted/alltrees.trees_cutted.newick")


for tree in trees:
    tree.midpoint_root()

# tree.midpoint_root()
## print(tree.to_newick())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       1 trees = read_newick("./data/alltrees_treees_cutted/alltrees.trees_cutted.newick")
#       4 for tree in trees:
# ----> 5     tree.midpoint_root()
#       7 # tree.midpoint_root()
#       8 ## print(tree.to_newick())
#
# File ~/Projects/BranchArchitect/brancharchitect/tree.py:423, in Node.midpoint_root(self)
#     420 final_root = cast(Self, _flip_upward(new_root))
#     422 # 6. Maintain tree properties
# --> 423 final_root._order = original_root._order.copy()
#     424 # Correct the call by providing the encoding argument
#     425 final_root._initialize_split_indices(self._encoding)
#
# AttributeError: 'tuple' object has no attribute 'copy'
