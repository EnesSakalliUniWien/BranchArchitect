# %%
# %load_ext autoreload
# %autoreload 2

# In a Jupyter Notebook cell
import logging
from brancharchitect.io import read_newick
from brancharchitect.rooting import midpoint_root

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
trees = read_newick("./data/alltrees_treees_cutted/alltrees.trees_cutted.newick")
root_trees = []
for tree in trees:
    # Root the tree
    root_trees.append(midpoint_root(tree))

# %%
trees = read_newick("./data/output_norovirus_window_size_200_20/best_trees.newick")
root_trees = []
for tree in trees:
    # Root the tree
    root_trees.append(midpoint_root(tree))

# %%
trees = read_newick("./data/output_norovirus_window_size_200_10/best_trees.newick")
root_trees = []
for tree in trees:
    # Root the tree
    root_trees.append(midpoint_root(tree))
