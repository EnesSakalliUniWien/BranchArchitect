# %%
# %load_ext autoreload
# %autoreload 2

# In a Jupyter Notebook cell
import logging
from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize
# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
file_path = "./../data/five_taxa_all_permutations.newick"

profile_and_visualize(
    filepath=file_path,
    bidirectional=False,
    n_iterations=20,
)
# Out:
# INFO:root:Starting profiling...
# Original Order: No reordering or optimization; baseline.
# Fiedler Order Only: Applies consensus Fiedler (spectral) ordering to all trees, but no further optimization.
# TreeOrderOptimizer Local (forward): Runs the local optimizer in forward mode only (left-to-right).
# TreeOrderOptimizer Local (bidirectional): Runs the local optimizer in both directions (left-to-right and right-to-left).
# Fiedler + TreeOrderOptimizer (forward): Applies Fiedler ordering, then runs the local optimizer in forward mode.
# Fiedler + TreeOrderOptimizer (bidirectional): Applies Fiedler ordering, then runs the local optimizer in both directions.
# INFO:root:Profiling completed successfully.
# Profile Summary:
# Total time: 8.17s
# Number of unique functions: 17
#
# Top 5 time-consuming functions:
#                                                Function  Total Time (s)     Time %    Calls
# 14  <method 'encode' of 'ImagingEncoder' objects> (~:0)        1.257317  15.385178       41
# 13                             get_leaves (tree.py:286)        0.721438   8.827893   211926
# 9                                traverse (tree.py:213)        0.472656   5.783663  1317438
# 7                            add (partition_set.py:191)        0.289545   3.543022   663103
# 6                       __init__ (partition_set.py:137)        0.259232   3.172097   326013
#                                              Function                 Module  \
# 12                    get_current_order (tree.py:298)                tree.py
# 0                               cast (typing.py:2187)              typing.py
# 16  <method 'set_text' of 'matplotlib.ft2font.FT2F...                      ~
# 11                             __hash__ (tree.py:115)                tree.py
# 4               <built-in method builtins.hash> (~:0)                      ~
# 2           <method 'extend' of 'list' objects> (~:0)                      ~
# 3               <method 'add' of 'set' objects> (~:0)                      ~
# 5         <built-in method builtins.isinstance> (~:0)                      ~
# 1                               inner (typing.py:392)              typing.py
# 10                        __hash__ (partition.py:102)           partition.py
# 15  circular_distance_for_node_subset (circular_di...  circular_distances.py
# 8                             to_splits (tree.py:128)                tree.py
# 6                     __init__ (partition_set.py:137)       partition_set.py
# 7                          add (partition_set.py:191)       partition_set.py
# 9                              traverse (tree.py:213)                tree.py
# 13                           get_leaves (tree.py:286)                tree.py
# 14  <method 'encode' of 'ImagingEncoder' objects> ...                      ~
#
#     Line                                               Name    Calls  \
# 12   298                                  get_current_order   108407
# 0   2187                                               cast  2000417
# 16     0  <method 'set_text' of 'matplotlib.ft2font.FT2F...     1202
# 11   115                                           __hash__   145225
# 4      0                    <built-in method builtins.hash>  1454998
# 2      0                <method 'extend' of 'list' objects>  1338888
# 3      0                    <method 'add' of 'set' objects>   663186
# 5      0              <built-in method builtins.isinstance>  2329296
# 1    392                                              inner  1336136
# 10   102                                           __hash__  1245475
# 15    80                  circular_distance_for_node_subset    74100
# 8    128                                          to_splits   198589
# 6    137                                           __init__   326013
# 7    191                                                add   663103
# 9    213                                           traverse  1317438
# 13   286                                         get_leaves   211926
# 14     0      <method 'encode' of 'ImagingEncoder' objects>       41
#
#     Total Time (s)  Time/Call (ms)  Cumulative (s)     Time %  Callers
# 12        0.094236        0.000869        0.943846   1.153119       10
# 0         0.095438        0.000048        0.095438   1.167830       25
# 16        0.097027        0.080722        0.097027   1.187279        2
# 11        0.105730        0.000728        0.826653   1.293769        8
# 4         0.116594        0.000080        0.168652   1.426705       11
# 2         0.122175        0.000091        0.122176   1.494996       15
# 3         0.125185        0.000189        0.262545   1.531833        8
# 5         0.158049        0.000068        0.207379   1.933969      263
# 1         0.161036        0.000121        0.161295   1.970522        8
# 10        0.161144        0.000129        0.252869   1.971846        8
# 15        0.164367        0.002218        1.237894   2.011284        6
# 8         0.243616        0.001227        1.356386   2.981016        5
# 6         0.259232        0.000795        0.472400   3.172097        8
# 7         0.289545        0.000437        0.666579   3.543022       12
# 9         0.472656        0.000359        0.473205   5.783663        3
# 13        0.721438        0.003404        1.106272   8.827893       13
# 14        1.257317       30.666257        1.257317  15.385178        1

# %% [markdown]
# ## Benchmark: Fiedler Ordering + Classical Propagation Algorithm
# This cell benchmarks the effect of applying consensus Fiedler (spectral) ordering as a preprocessing step, followed by the classical propagation algorithm, and compares it to other methods.

# %%
from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize

file_path = "./../data//alltrees/alltrees.trees.newick"
# Optionally, visualize or profile
profile_and_visualize(
    filepath=file_path,
    bidirectional=False,
    n_iterations=20,
)
# Out:
# INFO:root:Starting profiling...
# Original Order: No reordering or optimization; baseline.
# Fiedler Order Only: Applies consensus Fiedler (spectral) ordering to all trees, but no further optimization.
# TreeOrderOptimizer Local (forward): Runs the local optimizer in forward mode only (left-to-right).
# TreeOrderOptimizer Local (bidirectional): Runs the local optimizer in both directions (left-to-right and right-to-left).
# Fiedler + TreeOrderOptimizer (forward): Applies Fiedler ordering, then runs the local optimizer in forward mode.
# Fiedler + TreeOrderOptimizer (bidirectional): Applies Fiedler ordering, then runs the local optimizer in both directions.
# INFO:root:Profiling completed successfully.
# Profile Summary:
# Total time: 31.69s
# Number of unique functions: 22
#
# Top 5 time-consuming functions:
#                            Function  Total Time (s)     Time %     Calls
# 12           traverse (tree.py:213)        4.034905  12.732815  11134463
# 9        add (partition_set.py:191)        2.273846   7.175499   5404512
# 11          to_splits (tree.py:128)        1.984986   6.263954   1616956
# 8   __init__ (partition_set.py:137)        1.963087   6.194847   2485585
# 17         get_leaves (tree.py:286)        1.632542   5.151758    491109
#                                              Function  \
# 2            <method 'items' of 'dict' objects> (~:0)
# 13                    __iter__ (partition_set.py:183)
# 1                               inner (typing.py:392)
# 6                <built-in method builtins.len> (~:0)
# 0                               cast (typing.py:2187)
# 7          isdisjoint (<frozen _collections_abc>:625)
# 21  classify_subtrees_using_set_ops (tree_order_ut...
# 18                __contains__ (partition_set.py:179)
# 20   _collect_subtree_splits (tree_order_utils.py:21)
# 10                           __eq__ (partition.py:54)
# 3               <method 'add' of 'set' objects> (~:0)
# 16                             __hash__ (tree.py:115)
# 4               <built-in method builtins.hash> (~:0)
# 15                               __eq__ (tree.py:110)
# 19  <method 'encode' of 'ImagingEncoder' objects> ...
# 5         <built-in method builtins.isinstance> (~:0)
# 14                        __hash__ (partition.py:102)
# 17                           get_leaves (tree.py:286)
# 8                     __init__ (partition_set.py:137)
# 11                            to_splits (tree.py:128)
# 9                          add (partition_set.py:191)
# 12                             traverse (tree.py:213)
#
#                        Module  Line  \
# 2                           ~     0
# 13           partition_set.py   183
# 1                   typing.py   392
# 6                           ~     0
# 0                   typing.py  2187
# 7   <frozen _collections_abc>   625
# 21        tree_order_utils.py    51
# 18           partition_set.py   179
# 20        tree_order_utils.py    21
# 10               partition.py    54
# 3                           ~     0
# 16                    tree.py   115
# 4                           ~     0
# 15                    tree.py   110
# 19                          ~     0
# 5                           ~     0
# 14               partition.py   102
# 17                    tree.py   286
# 8            partition_set.py   137
# 11                    tree.py   128
# 9            partition_set.py   191
# 12                    tree.py   213
#
#                                              Name     Calls  Total Time (s)  \
# 2              <method 'items' of 'dict' objects>   3465920        0.322078
# 13                                       __iter__   2893248        0.356480
# 1                                           inner   3059792        0.365145
# 6                  <built-in method builtins.len>   2206554        0.383032
# 0                                            cast   8465115        0.421614
# 7                                      isdisjoint    702380        0.472553
# 21                classify_subtrees_using_set_ops     35119        0.477081
# 18                                   __contains__   4446423        0.698395
# 20                        _collect_subtree_splits     35119        0.804539
# 10                                         __eq__   5762268        0.814314
# 3                 <method 'add' of 'set' objects>   5404582        0.973591
# 16                                       __hash__   1439574        1.025617
# 4                 <built-in method builtins.hash>  14284568        1.029687
# 15                                         __eq__   4566672        1.104855
# 19  <method 'encode' of 'ImagingEncoder' objects>        31        1.134904
# 5           <built-in method builtins.isinstance>  22287439        1.214637
# 14                                       __hash__  12535294        1.422878
# 17                                     get_leaves    491109        1.632542
# 8                                        __init__   2485585        1.963087
# 11                                      to_splits   1616956        1.984986
# 9                                             add   5404512        2.273846
# 12                                       traverse  11134463        4.034905
#
#     Time/Call (ms)  Cumulative (s)     Time %  Callers
# 2         0.000093        0.322078   1.016372       47
# 13        0.000123        0.574783   1.124932        9
# 1         0.000119        0.365365   1.152276        9
# 6         0.000174        0.564461   1.208722      142
# 0         0.000050        0.421614   1.330472       21
# 7         0.000673        1.659805   1.491219        2
# 21        0.013585       19.483156   1.505510        1
# 18        0.000157        1.516713   2.203901        4
# 20        0.022909        8.966996   2.538857        8
# 10        0.000141        1.094049   2.569702        8
# 3         0.000180        2.040315   3.072328        5
# 16        0.000712        8.848389   3.236504       19
# 4         0.000072        1.079019   3.249348       14
# 15        0.000242        2.184627   3.486555       11
# 19       36.609801        1.134904   3.581378        1
# 5         0.000054        1.348872   3.832989      199
# 14        0.000114        2.309381   4.490128       12
# 17        0.003324        2.470486   5.151758       16
# 8         0.000790        3.377358   6.194847        6
# 11        0.001228       11.132377   6.263954        6
# 9         0.000421        5.199385   7.175499       18
# 12        0.000362        4.041204  12.732815        5

# %%
from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize

file_path = "./../data/output_norovirus_window_size_200_20/best_trees.newick"
# Optionally, visualize or profile
profile_and_visualize(
    filepath=file_path,
    bidirectional=False,
    n_iterations=10,
)
# Out:
# INFO:root:Starting profiling...
# ERROR:root:An error occurred during profiling: name '_parse_newick' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
