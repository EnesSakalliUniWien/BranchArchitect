# %%
# %load_ext autoreload
# %autoreload 2

# In a Jupyter Notebook cell
import logging
from brancharchitect.leaforder.benchmark.benchmark_utilities import profile_and_visualize
# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
file_path = "/Users/berksakalli/Projects/BranchArchitect/test/colouring/trees/sequence_trees/ripple_effect_test/ripple_effect.newick"

profile_and_visualize(
    filepath=file_path,
    bidirectional=True,
    n_iterations=20,
)
# Out:
# INFO:root:Starting profiling...
# INFO:brancharchitect.leaforder.tree_order_optimiser:Starting tree order optimization with 20 iterations, bidirectional=False
# INFO:brancharchitect.leaforder.tree_order_optimiser:Starting tree order optimization with 20 iterations, bidirectional=False
# INFO:brancharchitect.leaforder.tree_order_optimiser:Optimizing 8 trees
# INFO:brancharchitect.leaforder.tree_order_optimiser:Optimizing 8 trees
# INFO:brancharchitect.leaforder.tree_order_optimiser:Starting optimization iteration 1/20
# INFO:brancharchitect.leaforder.tree_order_optimiser:No improvements found in iteration 1, stopping early
# INFO:brancharchitect.leaforder.tree_order_optimiser:Tree order optimization completed
# INFO:brancharchitect.leaforder.tree_order_optimiser:Starting tree order optimization with 20 iterations, bidirectional=True
# INFO:brancharchitect.leaforder.tree_order_optimiser:Optimizing 8 trees
# ...

# %% [markdown]
# ## Benchmark: Fiedler Ordering + Classical Propagation Algorithm
# This cell benchmarks the effect of applying consensus Fiedler (spectral) ordering as a preprocessing step, followed by the classical propagation algorithm, and compares it to other methods.

# %%
from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize

file_path = "./../data//alltrees/alltrees.trees.newick"
# Optionally, visualize or profile
profile_and_visualize(
    filepath=file_path,
    bidirectional=False,
    n_iterations=20,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize
#       3 file_path = "./../data//alltrees/alltrees.trees.newick"
#       4 # Optionally, visualize or profile
#
# ModuleNotFoundError: No module named 'brancharchitect.leaforder.benchmark_utilities'

# %%
from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize

file_path = "/Users/berksakalli/Projects/BranchArchitect/test/colouring/trees/sequence_trees"
# Optionally, visualize or profile
profile_and_visualize(
    filepath=file_path,
    bidirectional=False,
    n_iterations=10,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from brancharchitect.leaforder.benchmark_utilities import profile_and_visualize
#       3 file_path = "./../data/output_norovirus_window_size_200_20/best_trees.newick"
#       4 # Optionally, visualize or profile
#
# ModuleNotFoundError: No module named 'brancharchitect.leaforder.benchmark_utilities'
