# %%
# Necessary imports
from typing import List, Tuple, Any, Dict

# Import necessary modules from brancharchitect
from brancharchitect.io import read_newick
from brancharchitect.tree import Node
from brancharchitect.jumping_taxa.tree_interpolation import interpolate_tree
from brancharchitect.consensus import create_majority_consensus_tree

# Import necessary modules from brancharchitect

# ---------------------------------------------------------------------------------------------------
# Function Definitions
# ---------------------------------------------------------------------------------------------------


def node_to_list(node: Node) -> Any:
    """
    Convert a tree into a nested list representation.
    """
    if node.children is None:
        node.children = []
    if len(node.children) > 0:
        return [node_to_list(child) for child in node.children]
    else:
        return node.name if node.name is not None else "Unknown"


def flatten_tree_list(tree_list: Any) -> List[str]:
    """
    Flatten a nested tree list into a linear list of taxa names.
    """
    if isinstance(tree_list, list):
        flattened = []
        for element in tree_list:
            flattened.extend(flatten_tree_list(element))
        return flattened
    else:
        return [tree_list]


def generate_subtree_rotations(
    tree_list: Any, memo: Dict[str, List[List[str]]] = None
) -> List[List[str]]:
    """
    Generate permutations by rotating subtrees based on majority consensus groupings.
    At each node, consider only the original and reversed orders of its children.
    """
    if memo is None:
        memo = {}

    tree_str = str(tree_list)
    if tree_str in memo:
        return memo[tree_str]

    # Base case: if it's a leaf node, return it as a list of one permutation
    if not isinstance(tree_list, list):
        permutations = [[tree_list]]
        memo[tree_str] = permutations
        return permutations

    # Recursively generate rotations for each child
    child_permutations_list = []
    for child in tree_list:
        child_permutations = generate_subtree_rotations(child, memo)
        child_permutations_list.append(child_permutations)

    # At this node, consider original and reversed orders of the children
    permutations = []
    for order in [child_permutations_list, child_permutations_list[::-1]]:
        # Combine permutations from child subtrees
        for child_combination in zip(*order):
            flattened = []
            for child_perm in child_combination:
                flattened.extend(child_perm)
            permutations.append(flattened)

    memo[tree_str] = permutations
    return permutations


def find_best_permutation(
    permutation_list: List[List[str]], tree_list: List[Node]
) -> Tuple[List[str], float]:
    """
    Find the permutation that minimizes the total circular distance over the trajectory.
    """
    min_total_distance = float("inf")
    best_permutation = None

    for perm in permutation_list:
        total_distance = 0
        for tree in tree_list:
            original_order = get_taxa_circular_order(tree)
            distance = circular_distance(perm, original_order)
            total_distance += distance
        if total_distance < min_total_distance:
            min_total_distance = total_distance
            best_permutation = perm

    return best_permutation, min_total_distance


def reorder_tree_preserving_splits(tree: Node, permutation: List[str]) -> None:
    """
    Reorder the taxa in the tree according to the given permutation,
    while preserving the split_indices and tree topology.
    """
    taxa_order = {name: idx for idx, name in enumerate(permutation)}

    # Recursive function to reorder children
    def _reorder(node: Node):
        if node.children:
            # Reorder children based on the minimum index of their descendant taxa
            node.children.sort(
                key=lambda child: min(
                    taxa_order[leaf.name] for leaf in child.get_leaves()
                )
            )
            for child in node.children:
                _reorder(child)
        # Do not modify split_indices or other attributes that affect topology

    _reorder(tree)


def optimize_tree_pair(tree1: Node, tree2: Node):
    """
    Optimize the order between a pair of trees by rotating subtrees based on their consensus.
    """
    # Generate consensus tree for the pair
    interpolation_result = interpolate_tree(tree1, tree2)
    intermediate1 = interpolation_result[0]
    c1 = interpolation_result[1]
    c2 = interpolation_result[2]
    intermediate2 = interpolation_result[3]

    # Convert consensus tree to nested list
    pair_consensus_list = node_to_list(c1)  # Using c1 as the consensus

    # Generate permutations by rotating subtrees in the pair consensus tree
    pair_permutation_list = generate_subtree_rotations(pair_consensus_list)

    # Find the best permutation for this pair
    min_distance = float("inf")
    best_pair_permutation = None
    order1 = get_taxa_circular_order(tree1)
    order2 = get_taxa_circular_order(tree2)

    for perm in pair_permutation_list:
        distance = circular_distance(perm, order1) + circular_distance(perm, order2)
        if distance < min_distance:
            min_distance = distance
            best_pair_permutation = perm

    # Apply the best permutation to both trees and intermediates, preserving splits
    reorder_tree_preserving_splits(tree1, best_pair_permutation)
    reorder_tree_preserving_splits(tree2, best_pair_permutation)
    reorder_tree_preserving_splits(intermediate1, best_pair_permutation)
    reorder_tree_preserving_splits(c1, best_pair_permutation)
    reorder_tree_preserving_splits(c2, best_pair_permutation)
    reorder_tree_preserving_splits(intermediate2, best_pair_permutation)


def circular_distances_trees(trees: List[Node]) -> float:
    """
    Compute the average circular distance over a list of trees.
    """
    total_distance = 0.0
    num_pairs = len(trees) - 1
    for i in range(num_pairs):
        order1 = get_taxa_circular_order(trees[i])
        order2 = get_taxa_circular_order(trees[i + 1])
        distance = circular_distance(order1, order2)
        total_distance += distance
        print(f"Distance between tree {i} and tree {i + 1}: {distance}")
    return total_distance / num_pairs if num_pairs > 0 else 0


from brancharchitect.tree_order_optimisation import generate_permutations_on_randomness


# ---------------------------------------------------------------------------------------------------
# Main Code
# ---------------------------------------------------------------------------------------------------
# Read your trees
tree_file_path = "./../data/alltrees_treees_cutted/alltrees.trees_cutted.newick"  # Replace with your actual file path
tree_list = read_newick(tree_file_path)
min_perm = generate_permutations_on_randomness(tree_list)
tree_list = read_newick(tree_file_path, min_perm)
print(f"Loaded {len(tree_list)} trees.")


# Step 1: Compute the majority consensus tree
threshold = 0.99
mc_tree = create_majority_consensus_tree(tree_list, threshold=threshold)
print(f"Computed majority consensus tree with threshold {threshold}.")

# Convert consensus tree to nested list
consensus_tree_list = node_to_list(mc_tree)
# Step 2: Generate permutations by rotating subtrees
permutations = generate_subtree_rotations(consensus_tree_list)
print(f"Generated {len(permutations)} permutations.")

# Step 3: Find and apply the best permutation to the trajectory
best_permutation, min_total_distance = find_best_permutation(permutations, tree_list)
average_distance_before = min_total_distance / (len(tree_list) - 1)
print(f"\nBest permutation found with average distance {average_distance_before}:")
print(best_permutation)

# Apply the best permutation to all trees, including intermediates, preserving splits
for tree in tree_list:
    reorder_tree_preserving_splits(tree, best_permutation)

# Step 4: Optimize between pairs of trees, including intermediates
for i in range(len(tree_list) - 1):
    tree1 = tree_list[i]
    tree2 = tree_list[i + 1]
    # Optimize the order of the trees and intermediates
    optimize_tree_pair(tree1, tree2)

# Step 5: Compute the circular distances between consecutive trees after optimization
print("\nCircular distances between consecutive trees after optimization:")
average_distance_after = circular_distances_trees(tree_list)
print(
    f"\nAverage circular distance over the trajectory after optimization: {average_distance_after}"
)
# Out:
# Distance between tree 0 and tree 1: 0.0
# Distance between tree 1 and tree 2: 0.0
# Distance between tree 2 and tree 3: 0.0
# Distance between tree 3 and tree 4: 0.0
# Distance between tree 4 and tree 5: 0.0
# Distance between tree 5 and tree 6: 0.0
# Distance between tree 6 and tree 7: 0.0
# Distance between tree 7 and tree 8: 0.0
# Distance between tree 8 and tree 9: 0.0
# Distance between tree 9 and tree 10: 0.0
# Distance between tree 10 and tree 11: 0.0
# Distance between tree 11 and tree 12: 0.0
# Distance between tree 12 and tree 13: 0.0
# Distance between tree 13 and tree 14: 0.0
# Distance between tree 14 and tree 15: 0.0
# Distance between tree 15 and tree 16: 0.0
# Distance between tree 16 and tree 17: 0.0
# Distance between tree 17 and tree 18: 0.0
# Distance between tree 18 and tree 19: 0.0
# Distance between tree 19 and tree 20: 0.0
# Distance between tree 20 and tree 21: 0.0
# Distance between tree 21 and tree 22: 0.0
# Distance between tree 22 and tree 23: 0.0
# Distance between tree 23 and tree 24: 0.0
# Distance between tree 24 and tree 25: 0.0
# Distance between tree 25 and tree 26: 0.0
# Distance between tree 26 and tree 27: 0.0
# Distance between tree 27 and tree 28: 0.0
# Distance between tree 28 and tree 29: 0.0
# Distance between tree 29 and tree 30: 0.0
# Distance between tree 30 and tree 31: 0.0
# Distance between tree 31 and tree 32: 0.0
# Distance between tree 32 and tree 33: 0.0
# Distance between tree 33 and tree 34: 0.0
# Distance between tree 34 and tree 35: 0.0
# Distance between tree 35 and tree 36: 0.0
# Distance between tree 36 and tree 37: 0.0
# Distance between tree 37 and tree 38: 0.0
# Distance between tree 38 and tree 39: 0.0
# Distance between tree 39 and tree 40: 0.0
# Distance between tree 40 and tree 41: 0.0
# Distance between tree 41 and tree 42: 0.0
# Distance between tree 42 and tree 43: 0.07272727272727272
# Distance between tree 43 and tree 44: 0.0
# Distance between tree 44 and tree 45: 0.0
# Distance between tree 45 and tree 46: 0.0
# Distance between tree 46 and tree 47: 0.0
# Distance between tree 47 and tree 48: 0.0
# Distance between tree 48 and tree 49: 0.07272727272727272
# Distance between tree 49 and tree 50: 0.0
# Distance between tree 50 and tree 51: 0.0
# Distance between tree 51 and tree 52: 0.0
# Distance between tree 52 and tree 53: 0.0
# Distance between tree 53 and tree 54: 0.0
# Distance between tree 54 and tree 55: 0.0
# Distance between tree 55 and tree 56: 0.0
# Distance between tree 56 and tree 57: 0.2
# Distance between tree 57 and tree 58: 0.0
# Distance between tree 58 and tree 59: 0.0
# Distance between tree 59 and tree 60: 0.10909090909090909
# Distance between tree 60 and tree 61: 0.0
# Distance between tree 61 and tree 62: 0.0
# Distance between tree 62 and tree 63: 0.0
# Distance between tree 63 and tree 64: 0.0
# Distance between tree 64 and tree 65: 0.0
# Distance between tree 65 and tree 66: 0.0
# Distance between tree 66 and tree 67: 0.0
# Distance between tree 67 and tree 68: 0.0
# Distance between tree 68 and tree 69: 0.0
# Distance between tree 69 and tree 70: 0.0
# Distance between tree 70 and tree 71: 0.0
# Distance between tree 71 and tree 72: 0.0
# Distance between tree 72 and tree 73: 0.0
# Distance between tree 73 and tree 74: 0.0
# Distance between tree 74 and tree 75: 0.0
# Distance between tree 75 and tree 76: 0.0
# Distance between tree 76 and tree 77: 0.0
# Distance between tree 77 and tree 78: 0.0
# Distance between tree 78 and tree 79: 0.0
# Distance between tree 79 and tree 80: 0.0
# Distance between tree 80 and tree 81: 0.0
# Distance between tree 81 and tree 82: 0.0
# Distance between tree 82 and tree 83: 0.0
# Distance between tree 83 and tree 84: 0.0
# Distance between tree 84 and tree 85: 0.0
# Distance between tree 85 and tree 86: 0.0
# Distance between tree 86 and tree 87: 0.0
# Distance between tree 87 and tree 88: 0.0
# Distance between tree 88 and tree 89: 0.07272727272727272
# Distance between tree 89 and tree 90: 0.0
# Distance between tree 90 and tree 91: 0.0
# Distance between tree 91 and tree 92: 0.0
# Distance between tree 92 and tree 93: 0.07272727272727272
# Distance between tree 93 and tree 94: 0.0
# Distance between tree 94 and tree 95: 0.0
# Distance between tree 95 and tree 96: 0.0
# Distance between tree 96 and tree 97: 0.0
# Distance between tree 97 and tree 98: 0.0
# Distance between tree 98 and tree 99: 0.0
# Distance between tree 99 and tree 100: 0.0
# Distance between tree 100 and tree 101: 0.0
# Distance between tree 101 and tree 102: 0.0
# Distance between tree 102 and tree 103: 0.0
# Distance between tree 103 and tree 104: 0.0
# Distance between tree 104 and tree 105: 0.0
# Distance between tree 105 and tree 106: 0.0
# Distance between tree 106 and tree 107: 0.0
# Distance between tree 107 and tree 108: 0.0
# Distance between tree 108 and tree 109: 0.0
# Distance between tree 109 and tree 110: 0.0
# Distance between tree 110 and tree 111: 0.0
# Distance between tree 111 and tree 112: 0.0
# Distance between tree 112 and tree 113: 0.0
# Distance between tree 113 and tree 114: 0.0
# Distance between tree 114 and tree 115: 0.0
# Distance between tree 115 and tree 116: 0.0
# Distance between tree 116 and tree 117: 0.0
# Distance between tree 117 and tree 118: 0.2909090909090909
# Distance between tree 118 and tree 119: 0.0
# Distance between tree 119 and tree 120: 0.0
# Distance between tree 120 and tree 121: 0.0
# Distance between tree 121 and tree 122: 0.0
# Distance between tree 122 and tree 123: 0.0
# Distance between tree 123 and tree 124: 0.0
# Distance between tree 124 and tree 125: 0.0
# Distance between tree 125 and tree 126: 0.0
# Distance between tree 126 and tree 127: 0.0
# Distance between tree 127 and tree 128: 0.0
# Distance between tree 128 and tree 129: 0.0
# Distance between tree 129 and tree 130: 0.0
# Distance between tree 130 and tree 131: 0.43636363636363634
# Distance between tree 131 and tree 132: 0.0
# Distance between tree 132 and tree 133: 0.43636363636363634
# Distance between tree 133 and tree 134: 0.0
# Distance between tree 134 and tree 135: 0.0
# Distance between tree 135 and tree 136: 0.03636363636363636
# Distance between tree 136 and tree 137: 0.03636363636363636
# Distance between tree 137 and tree 138: 0.0
# Distance between tree 138 and tree 139: 0.0
# Distance between tree 139 and tree 140: 0.0
# Distance between tree 140 and tree 141: 0.0
# Distance between tree 141 and tree 142: 0.0
# Distance between tree 142 and tree 143: 0.0
# Distance between tree 143 and tree 144: 0.0
# Distance between tree 144 and tree 145: 0.0
# Distance between tree 145 and tree 146: 0.0
# Distance between tree 146 and tree 147: 0.0
# Distance between tree 147 and tree 148: 0.0
# Distance between tree 148 and tree 149: 0.0
# Distance between tree 149 and tree 150: 0.0
# Distance between tree 150 and tree 151: 0.0
# Distance between tree 151 and tree 152: 0.0
# Distance between tree 152 and tree 153: 0.0
# Distance between tree 153 and tree 154: 0.0
# Distance between tree 154 and tree 155: 0.0
# Distance between tree 155 and tree 156: 0.0
# Distance between tree 156 and tree 157: 0.0
# Distance between tree 157 and tree 158: 0.0
# Distance between tree 158 and tree 159: 0.0
# Distance between tree 159 and tree 160: 0.0
# Distance between tree 160 and tree 161: 0.0
# Distance between tree 161 and tree 162: 0.0
# Distance between tree 162 and tree 163: 0.0
# Distance between tree 163 and tree 164: 0.0
# Distance between tree 164 and tree 165: 0.0
# Distance between tree 165 and tree 166: 0.0
# Distance between tree 166 and tree 167: 0.0
# Distance between tree 167 and tree 168: 0.0
# Distance between tree 168 and tree 169: 0.0
# Distance between tree 169 and tree 170: 0.0
# Distance between tree 170 and tree 171: 0.0
# Distance between tree 171 and tree 172: 0.0
# Distance between tree 172 and tree 173: 0.0
# Distance between tree 173 and tree 174: 0.0
# Distance between tree 174 and tree 175: 0.0
# Distance between tree 175 and tree 176: 0.0
# Distance between tree 176 and tree 177: 0.0
# Distance between tree 177 and tree 178: 0.43636363636363634
# Distance between tree 178 and tree 179: 0.36363636363636365
# Distance between tree 179 and tree 180: 0.0
# Distance between tree 180 and tree 181: 0.0
# Distance between tree 181 and tree 182: 0.0
# Distance between tree 182 and tree 183: 0.0
# Distance between tree 183 and tree 184: 0.0
# Distance between tree 184 and tree 185: 0.0
# Distance between tree 185 and tree 186: 0.0
# Distance between tree 186 and tree 187: 0.0
# Distance between tree 187 and tree 188: 0.0
# Distance between tree 188 and tree 189: 0.0
# Distance between tree 189 and tree 190: 0.0
# Distance between tree 190 and tree 191: 0.0
# Distance between tree 191 and tree 192: 0.0
# Distance between tree 192 and tree 193: 0.0
# Distance between tree 193 and tree 194: 0.0
# Distance between tree 194 and tree 195: 0.0
# Distance between tree 195 and tree 196: 0.0
# Distance between tree 196 and tree 197: 0.0
# Distance between tree 197 and tree 198: 0.0
# Distance between tree 198 and tree 199: 0.0
# Distance between tree 199 and tree 200: 0.0
# Distance between tree 200 and tree 201: 0.0
# Distance between tree 201 and tree 202: 0.0
# Distance between tree 202 and tree 203: 0.0
# Distance between tree 203 and tree 204: 0.0
# Distance between tree 204 and tree 205: 0.0
# Distance between tree 205 and tree 206: 0.0
# Distance between tree 206 and tree 207: 0.0
# Distance between tree 207 and tree 208: 0.0
# Distance between tree 208 and tree 209: 0.0
# Distance between tree 209 and tree 210: 0.0
# Distance between tree 210 and tree 211: 0.0
# Distance between tree 211 and tree 212: 0.0
# Distance between tree 212 and tree 213: 0.0
# Distance between tree 213 and tree 214: 0.0
# Distance between tree 214 and tree 215: 0.0
# Distance between tree 215 and tree 216: 0.0
# Distance between tree 216 and tree 217: 0.0
# Distance between tree 217 and tree 218: 0.0
# Distance between tree 218 and tree 219: 0.0
# Distance between tree 219 and tree 220: 0.0
# Distance between tree 220 and tree 221: 0.0
# Distance between tree 221 and tree 222: 0.0
# Distance between tree 222 and tree 223: 0.0
# Distance between tree 223 and tree 224: 0.0
# Distance between tree 224 and tree 225: 0.0
# Distance between tree 225 and tree 226: 0.0
# Distance between tree 226 and tree 227: 0.0
# Distance between tree 227 and tree 228: 0.0
# Distance between tree 228 and tree 229: 0.0
# Distance between tree 229 and tree 230: 0.0
# Distance between tree 230 and tree 231: 0.0
# Distance between tree 231 and tree 232: 0.0
# Distance between tree 232 and tree 233: 0.0
# Distance between tree 233 and tree 234: 0.0
# Distance between tree 234 and tree 235: 0.07272727272727272
# Distance between tree 235 and tree 236: 0.0
# Distance between tree 236 and tree 237: 0.0
# Distance between tree 237 and tree 238: 0.0
# Distance between tree 238 and tree 239: 0.07272727272727272
# Distance between tree 239 and tree 240: 0.07272727272727272
# Distance between tree 240 and tree 241: 0.07272727272727272
# Distance between tree 241 and tree 242: 0.14545454545454545
# Distance between tree 0 and tree 1: 0.0
# Distance between tree 1 and tree 2: 0.0
# Distance between tree 2 and tree 3: 0.0
# Distance between tree 3 and tree 4: 0.0
# Distance between tree 4 and tree 5: 0.0
# Distance between tree 5 and tree 6: 0.0
# Distance between tree 6 and tree 7: 0.0
# Distance between tree 7 and tree 8: 0.0
# Distance between tree 8 and tree 9: 0.0
# Distance between tree 9 and tree 10: 0.0
# Distance between tree 10 and tree 11: 0.0
# Distance between tree 11 and tree 12: 0.0
# Distance between tree 12 and tree 13: 0.0
# Distance between tree 13 and tree 14: 0.0
# Distance between tree 14 and tree 15: 0.0
# Distance between tree 15 and tree 16: 0.0
# Distance between tree 16 and tree 17: 0.0
# Distance between tree 17 and tree 18: 0.0
# Distance between tree 18 and tree 19: 0.0
# Distance between tree 19 and tree 20: 0.0
# Distance between tree 20 and tree 21: 0.0
# Distance between tree 21 and tree 22: 0.0
# Distance between tree 22 and tree 23: 0.0
# Distance between tree 23 and tree 24: 0.0
# Distance between tree 24 and tree 25: 0.0
# Distance between tree 25 and tree 26: 0.0
# Distance between tree 26 and tree 27: 0.0
# Distance between tree 27 and tree 28: 0.0
# Distance between tree 28 and tree 29: 0.0
# Distance between tree 29 and tree 30: 0.0
# Distance between tree 30 and tree 31: 0.0
# Distance between tree 31 and tree 32: 0.0
# Distance between tree 32 and tree 33: 0.0
# Distance between tree 33 and tree 34: 0.0
# Distance between tree 34 and tree 35: 0.0
# Distance between tree 35 and tree 36: 0.0
# Distance between tree 36 and tree 37: 0.0
# Distance between tree 37 and tree 38: 0.0
# Distance between tree 38 and tree 39: 0.0
# Distance between tree 39 and tree 40: 0.0
# Distance between tree 40 and tree 41: 0.0
# Distance between tree 41 and tree 42: 0.0
# Distance between tree 42 and tree 43: 0.07272727272727272
# Distance between tree 43 and tree 44: 0.0
# Distance between tree 44 and tree 45: 0.0
# Distance between tree 45 and tree 46: 0.0
# Distance between tree 46 and tree 47: 0.0
# Distance between tree 47 and tree 48: 0.0
# Distance between tree 48 and tree 49: 0.07272727272727272
# Distance between tree 49 and tree 50: 0.0
# Distance between tree 50 and tree 51: 0.0
# Distance between tree 51 and tree 52: 0.0
# Distance between tree 52 and tree 53: 0.0
# Distance between tree 53 and tree 54: 0.0
# Distance between tree 54 and tree 55: 0.0
# Distance between tree 55 and tree 56: 0.0
# Distance between tree 56 and tree 57: 0.07272727272727272
# Distance between tree 57 and tree 58: 0.0
# Distance between tree 58 and tree 59: 0.0
# Distance between tree 59 and tree 60: 0.03636363636363636
# Distance between tree 60 and tree 61: 0.0
# Distance between tree 61 and tree 62: 0.0
# Distance between tree 62 and tree 63: 0.0
# Distance between tree 63 and tree 64: 0.0
# Distance between tree 64 and tree 65: 0.0
# Distance between tree 65 and tree 66: 0.0
# Distance between tree 66 and tree 67: 0.0
# Distance between tree 67 and tree 68: 0.0
# Distance between tree 68 and tree 69: 0.0
# Distance between tree 69 and tree 70: 0.0
# Distance between tree 70 and tree 71: 0.0
# Distance between tree 71 and tree 72: 0.0
# Distance between tree 72 and tree 73: 0.0
# Distance between tree 73 and tree 74: 0.0
# Distance between tree 74 and tree 75: 0.0
# Distance between tree 75 and tree 76: 0.0
# Distance between tree 76 and tree 77: 0.0
# Distance between tree 77 and tree 78: 0.0
# Distance between tree 78 and tree 79: 0.0
# Distance between tree 79 and tree 80: 0.0
# Distance between tree 80 and tree 81: 0.0
# Distance between tree 81 and tree 82: 0.0
# Distance between tree 82 and tree 83: 0.0
# Distance between tree 83 and tree 84: 0.0
# Distance between tree 84 and tree 85: 0.0
# Distance between tree 85 and tree 86: 0.0
# Distance between tree 86 and tree 87: 0.0
# Distance between tree 87 and tree 88: 0.0
# Distance between tree 88 and tree 89: 0.07272727272727272
# Distance between tree 89 and tree 90: 0.0
# Distance between tree 90 and tree 91: 0.0
# Distance between tree 91 and tree 92: 0.0
# Distance between tree 92 and tree 93: 0.07272727272727272
# Distance between tree 93 and tree 94: 0.0
# Distance between tree 94 and tree 95: 0.0
# Distance between tree 95 and tree 96: 0.0
# Distance between tree 96 and tree 97: 0.0
# Distance between tree 97 and tree 98: 0.0
# Distance between tree 98 and tree 99: 0.0
# Distance between tree 99 and tree 100: 0.0
# Distance between tree 100 and tree 101: 0.0
# Distance between tree 101 and tree 102: 0.0
# Distance between tree 102 and tree 103: 0.0
# Distance between tree 103 and tree 104: 0.0
# Distance between tree 104 and tree 105: 0.0
# Distance between tree 105 and tree 106: 0.0
# Distance between tree 106 and tree 107: 0.0
# Distance between tree 107 and tree 108: 0.0
# Distance between tree 108 and tree 109: 0.0
# Distance between tree 109 and tree 110: 0.0
# Distance between tree 110 and tree 111: 0.0
# Distance between tree 111 and tree 112: 0.0
# Distance between tree 112 and tree 113: 0.0
# Distance between tree 113 and tree 114: 0.0
# Distance between tree 114 and tree 115: 0.0
# Distance between tree 115 and tree 116: 0.0
# Distance between tree 116 and tree 117: 0.0
# Distance between tree 117 and tree 118: 0.4
# Distance between tree 118 and tree 119: 0.0
# Distance between tree 119 and tree 120: 0.0
# Distance between tree 120 and tree 121: 0.0
# Distance between tree 121 and tree 122: 0.0
# Distance between tree 122 and tree 123: 0.0
# Distance between tree 123 and tree 124: 0.0
# Distance between tree 124 and tree 125: 0.0
# Distance between tree 125 and tree 126: 0.0
# Distance between tree 126 and tree 127: 0.0
# Distance between tree 127 and tree 128: 0.0
# Distance between tree 128 and tree 129: 0.0
# Distance between tree 129 and tree 130: 0.0
# Distance between tree 130 and tree 131: 0.21818181818181817
# Distance between tree 131 and tree 132: 0.0
# Distance between tree 132 and tree 133: 0.21818181818181817
# Distance between tree 133 and tree 134: 0.0
# Distance between tree 134 and tree 135: 0.0
# Distance between tree 135 and tree 136: 0.0
# Distance between tree 136 and tree 137: 0.0
# Distance between tree 137 and tree 138: 0.0
# Distance between tree 138 and tree 139: 0.0
# Distance between tree 139 and tree 140: 0.0
# Distance between tree 140 and tree 141: 0.0
# Distance between tree 141 and tree 142: 0.0
# Distance between tree 142 and tree 143: 0.0
# Distance between tree 143 and tree 144: 0.0
# Distance between tree 144 and tree 145: 0.0
# Distance between tree 145 and tree 146: 0.0
# Distance between tree 146 and tree 147: 0.0
# Distance between tree 147 and tree 148: 0.0
# Distance between tree 148 and tree 149: 0.0
# Distance between tree 149 and tree 150: 0.0
# Distance between tree 150 and tree 151: 0.0
# Distance between tree 151 and tree 152: 0.0
# Distance between tree 152 and tree 153: 0.0
# Distance between tree 153 and tree 154: 0.0
# Distance between tree 154 and tree 155: 0.0
# Distance between tree 155 and tree 156: 0.0
# Distance between tree 156 and tree 157: 0.0
# Distance between tree 157 and tree 158: 0.0
# Distance between tree 158 and tree 159: 0.0
# Distance between tree 159 and tree 160: 0.0
# Distance between tree 160 and tree 161: 0.0
# Distance between tree 161 and tree 162: 0.0
# Distance between tree 162 and tree 163: 0.0
# Distance between tree 163 and tree 164: 0.0
# Distance between tree 164 and tree 165: 0.0
# Distance between tree 165 and tree 166: 0.0
# Distance between tree 166 and tree 167: 0.0
# Distance between tree 167 and tree 168: 0.0
# Distance between tree 168 and tree 169: 0.0
# Distance between tree 169 and tree 170: 0.0
# Distance between tree 170 and tree 171: 0.0
# Distance between tree 171 and tree 172: 0.0
# Distance between tree 172 and tree 173: 0.0
# Distance between tree 173 and tree 174: 0.0
# Distance between tree 174 and tree 175: 0.0
# Distance between tree 175 and tree 176: 0.0
# Distance between tree 176 and tree 177: 0.0
# Distance between tree 177 and tree 178: 0.509090909090909
# Distance between tree 178 and tree 179: 0.36363636363636365
# Distance between tree 179 and tree 180: 0.0
# Distance between tree 180 and tree 181: 0.0
# Distance between tree 181 and tree 182: 0.0
# Distance between tree 182 and tree 183: 0.0
# Distance between tree 183 and tree 184: 0.0
# Distance between tree 184 and tree 185: 0.0
# Distance between tree 185 and tree 186: 0.0
# Distance between tree 186 and tree 187: 0.0
# Distance between tree 187 and tree 188: 0.0
# Distance between tree 188 and tree 189: 0.0
# Distance between tree 189 and tree 190: 0.0
# Distance between tree 190 and tree 191: 0.0
# Distance between tree 191 and tree 192: 0.0
# Distance between tree 192 and tree 193: 0.0
# Distance between tree 193 and tree 194: 0.0
# Distance between tree 194 and tree 195: 0.0
# Distance between tree 195 and tree 196: 0.0
# Distance between tree 196 and tree 197: 0.0
# Distance between tree 197 and tree 198: 0.0
# Distance between tree 198 and tree 199: 0.0
# Distance between tree 199 and tree 200: 0.0
# Distance between tree 200 and tree 201: 0.0
# Distance between tree 201 and tree 202: 0.0
# Distance between tree 202 and tree 203: 0.0
# Distance between tree 203 and tree 204: 0.0
# Distance between tree 204 and tree 205: 0.0
# Distance between tree 205 and tree 206: 0.0
# Distance between tree 206 and tree 207: 0.0
# Distance between tree 207 and tree 208: 0.0
# Distance between tree 208 and tree 209: 0.0
# Distance between tree 209 and tree 210: 0.0
# Distance between tree 210 and tree 211: 0.0
# Distance between tree 211 and tree 212: 0.0
# Distance between tree 212 and tree 213: 0.0
# Distance between tree 213 and tree 214: 0.0
# Distance between tree 214 and tree 215: 0.0
# Distance between tree 215 and tree 216: 0.0
# Distance between tree 216 and tree 217: 0.0
# Distance between tree 217 and tree 218: 0.0
# Distance between tree 218 and tree 219: 0.0
# Distance between tree 219 and tree 220: 0.0
# Distance between tree 220 and tree 221: 0.0
# Distance between tree 221 and tree 222: 0.0
# Distance between tree 222 and tree 223: 0.0
# Distance between tree 223 and tree 224: 0.0
# Distance between tree 224 and tree 225: 0.0
# Distance between tree 225 and tree 226: 0.0
# Distance between tree 226 and tree 227: 0.0
# Distance between tree 227 and tree 228: 0.0
# Distance between tree 228 and tree 229: 0.0
# Distance between tree 229 and tree 230: 0.0
# Distance between tree 230 and tree 231: 0.0
# Distance between tree 231 and tree 232: 0.0
# Distance between tree 232 and tree 233: 0.0
# Distance between tree 233 and tree 234: 0.0
# Distance between tree 234 and tree 235: 0.0
# Distance between tree 235 and tree 236: 0.07272727272727272
# Distance between tree 236 and tree 237: 0.0
# Distance between tree 237 and tree 238: 0.0
# Distance between tree 238 and tree 239: 0.07272727272727272
# Distance between tree 239 and tree 240: 0.07272727272727272
# Distance between tree 240 and tree 241: 0.10909090909090909
# Distance between tree 241 and tree 242: 0.07272727272727272
# Distance between tree 0 and tree 1: 0.0
# Distance between tree 1 and tree 2: 0.0
# Distance between tree 2 and tree 3: 0.0
# Distance between tree 3 and tree 4: 0.0
# Distance between tree 4 and tree 5: 0.0
# Distance between tree 5 and tree 6: 0.0
# Distance between tree 6 and tree 7: 0.0
# Distance between tree 7 and tree 8: 0.0
# Distance between tree 8 and tree 9: 0.0
# Distance between tree 9 and tree 10: 0.0
# Distance between tree 10 and tree 11: 0.0
# Distance between tree 11 and tree 12: 0.0
# Distance between tree 12 and tree 13: 0.0
# Distance between tree 13 and tree 14: 0.0
# Distance between tree 14 and tree 15: 0.0
# Distance between tree 15 and tree 16: 0.0
# Distance between tree 16 and tree 17: 0.0
# Distance between tree 17 and tree 18: 0.0
# Distance between tree 18 and tree 19: 0.0
# Distance between tree 19 and tree 20: 0.0
# Distance between tree 20 and tree 21: 0.0
# Distance between tree 21 and tree 22: 0.0
# Distance between tree 22 and tree 23: 0.0
# Distance between tree 23 and tree 24: 0.0
# Distance between tree 24 and tree 25: 0.0
# Distance between tree 25 and tree 26: 0.0
# Distance between tree 26 and tree 27: 0.0
# Distance between tree 27 and tree 28: 0.0
# Distance between tree 28 and tree 29: 0.0
# Distance between tree 29 and tree 30: 0.0
# Distance between tree 30 and tree 31: 0.0
# Distance between tree 31 and tree 32: 0.0
# Distance between tree 32 and tree 33: 0.0
# Distance between tree 33 and tree 34: 0.0
# Distance between tree 34 and tree 35: 0.0
# Distance between tree 35 and tree 36: 0.0
# Distance between tree 36 and tree 37: 0.0
# Distance between tree 37 and tree 38: 0.0
# Distance between tree 38 and tree 39: 0.0
# Distance between tree 39 and tree 40: 0.0
# Distance between tree 40 and tree 41: 0.0
# Distance between tree 41 and tree 42: 0.0
# Distance between tree 42 and tree 43: 0.0
# Distance between tree 43 and tree 44: 0.0
# Distance between tree 44 and tree 45: 0.0
# Distance between tree 45 and tree 46: 0.0
# Distance between tree 46 and tree 47: 0.03636363636363636
# Distance between tree 47 and tree 48: 0.0
# Distance between tree 48 and tree 49: 0.03636363636363636
# Distance between tree 49 and tree 50: 0.0
# Distance between tree 50 and tree 51: 0.0
# Distance between tree 51 and tree 52: 0.0
# Distance between tree 52 and tree 53: 0.0
# Distance between tree 53 and tree 54: 0.0
# Distance between tree 54 and tree 55: 0.03636363636363636
# Distance between tree 55 and tree 56: 0.0
# Distance between tree 56 and tree 57: 0.5454545454545454
# Distance between tree 57 and tree 58: 0.0
# Distance between tree 58 and tree 59: 0.0
# Distance between tree 59 and tree 60: 0.14545454545454545
# Distance between tree 60 and tree 61: 0.0
# Distance between tree 61 and tree 62: 0.0
# Distance between tree 62 and tree 63: 0.0
# Distance between tree 63 and tree 64: 0.0
# Distance between tree 64 and tree 65: 0.0
# Distance between tree 65 and tree 66: 0.0
# Distance between tree 66 and tree 67: 0.0
# Distance between tree 67 and tree 68: 0.0
# Distance between tree 68 and tree 69: 0.0
# Distance between tree 69 and tree 70: 0.0
# Distance between tree 70 and tree 71: 0.0
# Distance between tree 71 and tree 72: 0.0
# Distance between tree 72 and tree 73: 0.0
# Distance between tree 73 and tree 74: 0.0
# Distance between tree 74 and tree 75: 0.0
# Distance between tree 75 and tree 76: 0.0
# Distance between tree 76 and tree 77: 0.0
# Distance between tree 77 and tree 78: 0.0
# Distance between tree 78 and tree 79: 0.0
# Distance between tree 79 and tree 80: 0.0
# Distance between tree 80 and tree 81: 0.0
# Distance between tree 81 and tree 82: 0.0
# Distance between tree 82 and tree 83: 0.0
# Distance between tree 83 and tree 84: 0.0
# Distance between tree 84 and tree 85: 0.0
# Distance between tree 85 and tree 86: 0.0
# Distance between tree 86 and tree 87: 0.0
# Distance between tree 87 and tree 88: 0.0
# Distance between tree 88 and tree 89: 0.07272727272727272
# Distance between tree 89 and tree 90: 0.0
# Distance between tree 90 and tree 91: 0.0
# Distance between tree 91 and tree 92: 0.0
# Distance between tree 92 and tree 93: 0.07272727272727272
# Distance between tree 93 and tree 94: 0.0
# Distance between tree 94 and tree 95: 0.0
# Distance between tree 95 and tree 96: 0.0
# Distance between tree 96 and tree 97: 0.0
# Distance between tree 97 and tree 98: 0.0
# Distance between tree 98 and tree 99: 0.0
# Distance between tree 99 and tree 100: 0.0
# Distance between tree 100 and tree 101: 0.0
# Distance between tree 101 and tree 102: 0.0
# Distance between tree 102 and tree 103: 0.0
# Distance between tree 103 and tree 104: 0.0
# Distance between tree 104 and tree 105: 0.0
# Distance between tree 105 and tree 106: 0.0
# Distance between tree 106 and tree 107: 0.0
# Distance between tree 107 and tree 108: 0.0
# Distance between tree 108 and tree 109: 0.0
# Distance between tree 109 and tree 110: 0.0
# Distance between tree 110 and tree 111: 0.0
# Distance between tree 111 and tree 112: 0.0
# Distance between tree 112 and tree 113: 0.0
# Distance between tree 113 and tree 114: 0.0
# Distance between tree 114 and tree 115: 0.0
# Distance between tree 115 and tree 116: 0.0
# Distance between tree 116 and tree 117: 0.0
# Distance between tree 117 and tree 118: 0.07272727272727272
# Distance between tree 118 and tree 119: 0.0
# Distance between tree 119 and tree 120: 0.0
# Distance between tree 120 and tree 121: 0.0
# Distance between tree 121 and tree 122: 0.0
# Distance between tree 122 and tree 123: 0.0
# Distance between tree 123 and tree 124: 0.0
# Distance between tree 124 and tree 125: 0.0
# Distance between tree 125 and tree 126: 0.0
# Distance between tree 126 and tree 127: 0.0
# Distance between tree 127 and tree 128: 0.0
# Distance between tree 128 and tree 129: 0.0
# Distance between tree 129 and tree 130: 0.0
# Distance between tree 130 and tree 131: 0.0
# Distance between tree 131 and tree 132: 0.0
# Distance between tree 132 and tree 133: 0.0
# Distance between tree 133 and tree 134: 0.0
# Distance between tree 134 and tree 135: 0.0
# Distance between tree 135 and tree 136: 0.0
# Distance between tree 136 and tree 137: 0.0
# Distance between tree 137 and tree 138: 0.0
# Distance between tree 138 and tree 139: 0.0
# Distance between tree 139 and tree 140: 0.0
# Distance between tree 140 and tree 141: 0.0
# Distance between tree 141 and tree 142: 0.0
# Distance between tree 142 and tree 143: 0.0
# Distance between tree 143 and tree 144: 0.0
# Distance between tree 144 and tree 145: 0.0
# Distance between tree 145 and tree 146: 0.0
# Distance between tree 146 and tree 147: 0.0
# Distance between tree 147 and tree 148: 0.0
# Distance between tree 148 and tree 149: 0.0
# Distance between tree 149 and tree 150: 0.0
# Distance between tree 150 and tree 151: 0.0
# Distance between tree 151 and tree 152: 0.0
# Distance between tree 152 and tree 153: 0.0
# Distance between tree 153 and tree 154: 0.0
# Distance between tree 154 and tree 155: 0.0
# Distance between tree 155 and tree 156: 0.0
# Distance between tree 156 and tree 157: 0.0
# Distance between tree 157 and tree 158: 0.0
# Distance between tree 158 and tree 159: 0.0
# Distance between tree 159 and tree 160: 0.0
# Distance between tree 160 and tree 161: 0.0
# Distance between tree 161 and tree 162: 0.0
# Distance between tree 162 and tree 163: 0.0
# Distance between tree 163 and tree 164: 0.0
# Distance between tree 164 and tree 165: 0.0
# Distance between tree 165 and tree 166: 0.0
# Distance between tree 166 and tree 167: 0.0
# Distance between tree 167 and tree 168: 0.0
# Distance between tree 168 and tree 169: 0.0
# Distance between tree 169 and tree 170: 0.0
# Distance between tree 170 and tree 171: 0.0
# Distance between tree 171 and tree 172: 0.0
# Distance between tree 172 and tree 173: 0.0
# Distance between tree 173 and tree 174: 0.0
# Distance between tree 174 and tree 175: 0.0
# Distance between tree 175 and tree 176: 0.0
# Distance between tree 176 and tree 177: 0.0
# Distance between tree 177 and tree 178: 0.07272727272727272
# Distance between tree 178 and tree 179: 0.0
# Distance between tree 179 and tree 180: 0.0
# Distance between tree 180 and tree 181: 0.0
# Distance between tree 181 and tree 182: 0.0
# Distance between tree 182 and tree 183: 0.0
# Distance between tree 183 and tree 184: 0.0
# Distance between tree 184 and tree 185: 0.0
# Distance between tree 185 and tree 186: 0.0
# Distance between tree 186 and tree 187: 0.0
# Distance between tree 187 and tree 188: 0.0
# Distance between tree 188 and tree 189: 0.0
# Distance between tree 189 and tree 190: 0.0
# Distance between tree 190 and tree 191: 0.0
# Distance between tree 191 and tree 192: 0.0
# Distance between tree 192 and tree 193: 0.0
# Distance between tree 193 and tree 194: 0.0
# Distance between tree 194 and tree 195: 0.0
# Distance between tree 195 and tree 196: 0.0
# Distance between tree 196 and tree 197: 0.0
# Distance between tree 197 and tree 198: 0.0
# Distance between tree 198 and tree 199: 0.0
# Distance between tree 199 and tree 200: 0.0
# Distance between tree 200 and tree 201: 0.0
# Distance between tree 201 and tree 202: 0.0
# Distance between tree 202 and tree 203: 0.0
# Distance between tree 203 and tree 204: 0.0
# Distance between tree 204 and tree 205: 0.0
# Distance between tree 205 and tree 206: 0.0
# Distance between tree 206 and tree 207: 0.0
# Distance between tree 207 and tree 208: 0.0
# Distance between tree 208 and tree 209: 0.0
# Distance between tree 209 and tree 210: 0.0
# Distance between tree 210 and tree 211: 0.0
# Distance between tree 211 and tree 212: 0.0
# Distance between tree 212 and tree 213: 0.0
# Distance between tree 213 and tree 214: 0.0
# Distance between tree 214 and tree 215: 0.0
# Distance between tree 215 and tree 216: 0.0
# Distance between tree 216 and tree 217: 0.0
# Distance between tree 217 and tree 218: 0.0
# Distance between tree 218 and tree 219: 0.0
# Distance between tree 219 and tree 220: 0.0
# Distance between tree 220 and tree 221: 0.0
# Distance between tree 221 and tree 222: 0.0
# Distance between tree 222 and tree 223: 0.0
# Distance between tree 223 and tree 224: 0.0
# Distance between tree 224 and tree 225: 0.0
# Distance between tree 225 and tree 226: 0.0
# Distance between tree 226 and tree 227: 0.0
# Distance between tree 227 and tree 228: 0.0
# Distance between tree 228 and tree 229: 0.0
# Distance between tree 229 and tree 230: 0.0
# Distance between tree 230 and tree 231: 0.0
# Distance between tree 231 and tree 232: 0.0
# Distance between tree 232 and tree 233: 0.0
# Distance between tree 233 and tree 234: 0.0
# Distance between tree 234 and tree 235: 0.07272727272727272
# Distance between tree 235 and tree 236: 0.0
# Distance between tree 236 and tree 237: 0.0
# Distance between tree 237 and tree 238: 0.0
# Distance between tree 238 and tree 239: 0.07272727272727272
# Distance between tree 239 and tree 240: 0.07272727272727272
# Distance between tree 240 and tree 241: 0.10909090909090909
# Distance between tree 241 and tree 242: 0.14545454545454545
# Distance between tree 0 and tree 1: 0.0
# Distance between tree 1 and tree 2: 0.0
# Distance between tree 2 and tree 3: 0.0
# Distance between tree 3 and tree 4: 0.0
# Distance between tree 4 and tree 5: 0.0
# Distance between tree 5 and tree 6: 0.0
# Distance between tree 6 and tree 7: 0.0
# Distance between tree 7 and tree 8: 0.0
# Distance between tree 8 and tree 9: 0.0
# Distance between tree 9 and tree 10: 0.0
# Distance between tree 10 and tree 11: 0.0
# Distance between tree 11 and tree 12: 0.0
# Distance between tree 12 and tree 13: 0.0
# Distance between tree 13 and tree 14: 0.0
# Distance between tree 14 and tree 15: 0.0
# Distance between tree 15 and tree 16: 0.0
# Distance between tree 16 and tree 17: 0.0
# Distance between tree 17 and tree 18: 0.0
# Distance between tree 18 and tree 19: 0.0
# Distance between tree 19 and tree 20: 0.0
# Distance between tree 20 and tree 21: 0.0
# Distance between tree 21 and tree 22: 0.0
# Distance between tree 22 and tree 23: 0.0
# Distance between tree 23 and tree 24: 0.0
# Distance between tree 24 and tree 25: 0.0
# Distance between tree 25 and tree 26: 0.0
# Distance between tree 26 and tree 27: 0.0
# Distance between tree 27 and tree 28: 0.0
# Distance between tree 28 and tree 29: 0.0
# Distance between tree 29 and tree 30: 0.0
# Distance between tree 30 and tree 31: 0.0
# Distance between tree 31 and tree 32: 0.0
# Distance between tree 32 and tree 33: 0.0
# Distance between tree 33 and tree 34: 0.0
# Distance between tree 34 and tree 35: 0.0
# Distance between tree 35 and tree 36: 0.0
# Distance between tree 36 and tree 37: 0.0
# Distance between tree 37 and tree 38: 0.0
# Distance between tree 38 and tree 39: 0.0
# Distance between tree 39 and tree 40: 0.0
# Distance between tree 40 and tree 41: 0.0
# Distance between tree 41 and tree 42: 0.0
# Distance between tree 42 and tree 43: 0.0
# Distance between tree 43 and tree 44: 0.0
# Distance between tree 44 and tree 45: 0.0
# Distance between tree 45 and tree 46: 0.0
# Distance between tree 46 and tree 47: 0.07272727272727272
# Distance between tree 47 and tree 48: 0.0
# Distance between tree 48 and tree 49: 0.07272727272727272
# Distance between tree 49 and tree 50: 0.0
# Distance between tree 50 and tree 51: 0.0
# Distance between tree 51 and tree 52: 0.0
# Distance between tree 52 and tree 53: 0.0
# Distance between tree 53 and tree 54: 0.0
# Distance between tree 54 and tree 55: 0.03636363636363636
# Distance between tree 55 and tree 56: 0.0
# Distance between tree 56 and tree 57: 0.07272727272727272
# Distance between tree 57 and tree 58: 0.0
# Distance between tree 58 and tree 59: 0.0
# Distance between tree 59 and tree 60: 0.10909090909090909
# Distance between tree 60 and tree 61: 0.0
# Distance between tree 61 and tree 62: 0.0
# Distance between tree 62 and tree 63: 0.0
# Distance between tree 63 and tree 64: 0.0
# Distance between tree 64 and tree 65: 0.0
# Distance between tree 65 and tree 66: 0.0
# Distance between tree 66 and tree 67: 0.0
# Distance between tree 67 and tree 68: 0.0
# Distance between tree 68 and tree 69: 0.0
# Distance between tree 69 and tree 70: 0.0
# Distance between tree 70 and tree 71: 0.0
# Distance between tree 71 and tree 72: 0.0
# Distance between tree 72 and tree 73: 0.0
# Distance between tree 73 and tree 74: 0.0
# Distance between tree 74 and tree 75: 0.0
# Distance between tree 75 and tree 76: 0.0
# Distance between tree 76 and tree 77: 0.0
# Distance between tree 77 and tree 78: 0.0
# Distance between tree 78 and tree 79: 0.0
# Distance between tree 79 and tree 80: 0.0
# Distance between tree 80 and tree 81: 0.0
# Distance between tree 81 and tree 82: 0.0
# Distance between tree 82 and tree 83: 0.0
# Distance between tree 83 and tree 84: 0.0
# Distance between tree 84 and tree 85: 0.0
# Distance between tree 85 and tree 86: 0.0
# Distance between tree 86 and tree 87: 0.0
# Distance between tree 87 and tree 88: 0.0
# Distance between tree 88 and tree 89: 0.07272727272727272
# Distance between tree 89 and tree 90: 0.0
# Distance between tree 90 and tree 91: 0.0
# Distance between tree 91 and tree 92: 0.0
# Distance between tree 92 and tree 93: 0.07272727272727272
# Distance between tree 93 and tree 94: 0.0
# Distance between tree 94 and tree 95: 0.0
# Distance between tree 95 and tree 96: 0.0
# Distance between tree 96 and tree 97: 0.0
# Distance between tree 97 and tree 98: 0.0
# Distance between tree 98 and tree 99: 0.0
# Distance between tree 99 and tree 100: 0.0
# Distance between tree 100 and tree 101: 0.0
# Distance between tree 101 and tree 102: 0.0
# Distance between tree 102 and tree 103: 0.0
# Distance between tree 103 and tree 104: 0.0
# Distance between tree 104 and tree 105: 0.0
# Distance between tree 105 and tree 106: 0.0
# Distance between tree 106 and tree 107: 0.0
# Distance between tree 107 and tree 108: 0.0
# Distance between tree 108 and tree 109: 0.0
# Distance between tree 109 and tree 110: 0.0
# Distance between tree 110 and tree 111: 0.0
# Distance between tree 111 and tree 112: 0.0
# Distance between tree 112 and tree 113: 0.0
# Distance between tree 113 and tree 114: 0.0
# Distance between tree 114 and tree 115: 0.0
# Distance between tree 115 and tree 116: 0.0
# Distance between tree 116 and tree 117: 0.0
# Distance between tree 117 and tree 118: 0.21818181818181817
# Distance between tree 118 and tree 119: 0.0
# Distance between tree 119 and tree 120: 0.0
# Distance between tree 120 and tree 121: 0.0
# Distance between tree 121 and tree 122: 0.0
# Distance between tree 122 and tree 123: 0.0
# Distance between tree 123 and tree 124: 0.0
# Distance between tree 124 and tree 125: 0.0
# Distance between tree 125 and tree 126: 0.0
# Distance between tree 126 and tree 127: 0.0
# Distance between tree 127 and tree 128: 0.0
# Distance between tree 128 and tree 129: 0.0
# Distance between tree 129 and tree 130: 0.0
# Distance between tree 130 and tree 131: 0.2909090909090909
# Distance between tree 131 and tree 132: 0.0
# Distance between tree 132 and tree 133: 0.2909090909090909
# Distance between tree 133 and tree 134: 0.0
# Distance between tree 134 and tree 135: 0.0
# Distance between tree 135 and tree 136: 0.03636363636363636
# Distance between tree 136 and tree 137: 0.03636363636363636
# Distance between tree 137 and tree 138: 0.0
# Distance between tree 138 and tree 139: 0.0
# Distance between tree 139 and tree 140: 0.0
# Distance between tree 140 and tree 141: 0.0
# Distance between tree 141 and tree 142: 0.0
# Distance between tree 142 and tree 143: 0.0
# Distance between tree 143 and tree 144: 0.0
# Distance between tree 144 and tree 145: 0.0
# Distance between tree 145 and tree 146: 0.0
# Distance between tree 146 and tree 147: 0.0
# Distance between tree 147 and tree 148: 0.0
# Distance between tree 148 and tree 149: 0.0
# Distance between tree 149 and tree 150: 0.0
# Distance between tree 150 and tree 151: 0.0
# Distance between tree 151 and tree 152: 0.0
# Distance between tree 152 and tree 153: 0.0
# Distance between tree 153 and tree 154: 0.0
# Distance between tree 154 and tree 155: 0.0
# Distance between tree 155 and tree 156: 0.0
# Distance between tree 156 and tree 157: 0.0
# Distance between tree 157 and tree 158: 0.0
# Distance between tree 158 and tree 159: 0.0
# Distance between tree 159 and tree 160: 0.0
# Distance between tree 160 and tree 161: 0.0
# Distance between tree 161 and tree 162: 0.0
# Distance between tree 162 and tree 163: 0.0
# Distance between tree 163 and tree 164: 0.0
# Distance between tree 164 and tree 165: 0.0
# Distance between tree 165 and tree 166: 0.0
# Distance between tree 166 and tree 167: 0.0
# Distance between tree 167 and tree 168: 0.0
# Distance between tree 168 and tree 169: 0.0
# Distance between tree 169 and tree 170: 0.0
# Distance between tree 170 and tree 171: 0.0
# Distance between tree 171 and tree 172: 0.0
# Distance between tree 172 and tree 173: 0.0
# Distance between tree 173 and tree 174: 0.0
# Distance between tree 174 and tree 175: 0.0
# Distance between tree 175 and tree 176: 0.0
# Distance between tree 176 and tree 177: 0.0
# Distance between tree 177 and tree 178: 0.2909090909090909
# Distance between tree 178 and tree 179: 0.14545454545454545
# Distance between tree 179 and tree 180: 0.0
# Distance between tree 180 and tree 181: 0.0
# Distance between tree 181 and tree 182: 0.0
# Distance between tree 182 and tree 183: 0.0
# Distance between tree 183 and tree 184: 0.0
# Distance between tree 184 and tree 185: 0.0
# Distance between tree 185 and tree 186: 0.0
# Distance between tree 186 and tree 187: 0.0
# Distance between tree 187 and tree 188: 0.0
# Distance between tree 188 and tree 189: 0.0
# Distance between tree 189 and tree 190: 0.0
# Distance between tree 190 and tree 191: 0.0
# Distance between tree 191 and tree 192: 0.0
# Distance between tree 192 and tree 193: 0.0
# Distance between tree 193 and tree 194: 0.0
# Distance between tree 194 and tree 195: 0.0
# Distance between tree 195 and tree 196: 0.0
# Distance between tree 196 and tree 197: 0.0
# Distance between tree 197 and tree 198: 0.0
# Distance between tree 198 and tree 199: 0.0
# Distance between tree 199 and tree 200: 0.0
# Distance between tree 200 and tree 201: 0.0
# Distance between tree 201 and tree 202: 0.0
# Distance between tree 202 and tree 203: 0.0
# Distance between tree 203 and tree 204: 0.0
# Distance between tree 204 and tree 205: 0.0
# Distance between tree 205 and tree 206: 0.0
# Distance between tree 206 and tree 207: 0.0
# Distance between tree 207 and tree 208: 0.0
# Distance between tree 208 and tree 209: 0.0
# Distance between tree 209 and tree 210: 0.0
# Distance between tree 210 and tree 211: 0.0
# Distance between tree 211 and tree 212: 0.0
# Distance between tree 212 and tree 213: 0.0
# Distance between tree 213 and tree 214: 0.0
# Distance between tree 214 and tree 215: 0.0
# Distance between tree 215 and tree 216: 0.0
# Distance between tree 216 and tree 217: 0.0
# Distance between tree 217 and tree 218: 0.0
# Distance between tree 218 and tree 219: 0.0
# Distance between tree 219 and tree 220: 0.0
# Distance between tree 220 and tree 221: 0.0
# Distance between tree 221 and tree 222: 0.0
# Distance between tree 222 and tree 223: 0.0
# Distance between tree 223 and tree 224: 0.0
# Distance between tree 224 and tree 225: 0.0
# Distance between tree 225 and tree 226: 0.0
# Distance between tree 226 and tree 227: 0.0
# Distance between tree 227 and tree 228: 0.0
# Distance between tree 228 and tree 229: 0.0
# Distance between tree 229 and tree 230: 0.0
# Distance between tree 230 and tree 231: 0.0
# Distance between tree 231 and tree 232: 0.0
# Distance between tree 232 and tree 233: 0.0
# Distance between tree 233 and tree 234: 0.0
# Distance between tree 234 and tree 235: 0.0
# Distance between tree 235 and tree 236: 0.07272727272727272
# Distance between tree 236 and tree 237: 0.0
# Distance between tree 237 and tree 238: 0.0
# Distance between tree 238 and tree 239: 0.07272727272727272
# Distance between tree 239 and tree 240: 0.07272727272727272
# Distance between tree 240 and tree 241: 0.07272727272727272
# Distance between tree 241 and tree 242: 0.10909090909090909
# Distance between tree 0 and tree 1: 0.0
# Distance between tree 1 and tree 2: 0.0
# Distance between tree 2 and tree 3: 0.0
# Distance between tree 3 and tree 4: 0.0
# Distance between tree 4 and tree 5: 0.0
# Distance between tree 5 and tree 6: 0.0
# Distance between tree 6 and tree 7: 0.0
# Distance between tree 7 and tree 8: 0.0
# Distance between tree 8 and tree 9: 0.0
# Distance between tree 9 and tree 10: 0.0
# Distance between tree 10 and tree 11: 0.0
# Distance between tree 11 and tree 12: 0.0
# Distance between tree 12 and tree 13: 0.0
# Distance between tree 13 and tree 14: 0.0
# Distance between tree 14 and tree 15: 0.0
# Distance between tree 15 and tree 16: 0.0
# Distance between tree 16 and tree 17: 0.0
# Distance between tree 17 and tree 18: 0.0
# Distance between tree 18 and tree 19: 0.0
# Distance between tree 19 and tree 20: 0.0
# Distance between tree 20 and tree 21: 0.0
# Distance between tree 21 and tree 22: 0.0
# Distance between tree 22 and tree 23: 0.0
# Distance between tree 23 and tree 24: 0.0
# Distance between tree 24 and tree 25: 0.0
# Distance between tree 25 and tree 26: 0.0
# Distance between tree 26 and tree 27: 0.0
# Distance between tree 27 and tree 28: 0.0
# Distance between tree 28 and tree 29: 0.0
# Distance between tree 29 and tree 30: 0.0
# Distance between tree 30 and tree 31: 0.0
# Distance between tree 31 and tree 32: 0.0
# Distance between tree 32 and tree 33: 0.0
# Distance between tree 33 and tree 34: 0.0
# Distance between tree 34 and tree 35: 0.0
# Distance between tree 35 and tree 36: 0.0
# Distance between tree 36 and tree 37: 0.0
# Distance between tree 37 and tree 38: 0.0
# Distance between tree 38 and tree 39: 0.0
# Distance between tree 39 and tree 40: 0.0
# Distance between tree 40 and tree 41: 0.0
# Distance between tree 41 and tree 42: 0.0
# Distance between tree 42 and tree 43: 0.0
# Distance between tree 43 and tree 44: 0.0
# Distance between tree 44 and tree 45: 0.0
# Distance between tree 45 and tree 46: 0.0
# Distance between tree 46 and tree 47: 0.03636363636363636
# Distance between tree 47 and tree 48: 0.0
# Distance between tree 48 and tree 49: 0.03636363636363636
# Distance between tree 49 and tree 50: 0.0
# Distance between tree 50 and tree 51: 0.0
# Distance between tree 51 and tree 52: 0.0
# Distance between tree 52 and tree 53: 0.0
# Distance between tree 53 and tree 54: 0.0
# Distance between tree 54 and tree 55: 0.0
# Distance between tree 55 and tree 56: 0.0
# Distance between tree 56 and tree 57: 0.07272727272727272
# Distance between tree 57 and tree 58: 0.0
# Distance between tree 58 and tree 59: 0.0
# Distance between tree 59 and tree 60: 0.03636363636363636
# Distance between tree 60 and tree 61: 0.0
# Distance between tree 61 and tree 62: 0.0
# Distance between tree 62 and tree 63: 0.0
# Distance between tree 63 and tree 64: 0.0
# Distance between tree 64 and tree 65: 0.0
# Distance between tree 65 and tree 66: 0.0
# Distance between tree 66 and tree 67: 0.0
# Distance between tree 67 and tree 68: 0.0
# Distance between tree 68 and tree 69: 0.0
# Distance between tree 69 and tree 70: 0.0
# Distance between tree 70 and tree 71: 0.0
# Distance between tree 71 and tree 72: 0.0
# Distance between tree 72 and tree 73: 0.0
# Distance between tree 73 and tree 74: 0.0
# Distance between tree 74 and tree 75: 0.0
# Distance between tree 75 and tree 76: 0.0
# Distance between tree 76 and tree 77: 0.0
# Distance between tree 77 and tree 78: 0.0
# Distance between tree 78 and tree 79: 0.0
# Distance between tree 79 and tree 80: 0.0
# Distance between tree 80 and tree 81: 0.0
# Distance between tree 81 and tree 82: 0.0
# Distance between tree 82 and tree 83: 0.0
# Distance between tree 83 and tree 84: 0.0
# Distance between tree 84 and tree 85: 0.0
# Distance between tree 85 and tree 86: 0.0
# Distance between tree 86 and tree 87: 0.0
# Distance between tree 87 and tree 88: 0.0
# Distance between tree 88 and tree 89: 0.07272727272727272
# Distance between tree 89 and tree 90: 0.0
# Distance between tree 90 and tree 91: 0.0
# Distance between tree 91 and tree 92: 0.0
# Distance between tree 92 and tree 93: 0.07272727272727272
# Distance between tree 93 and tree 94: 0.0
# Distance between tree 94 and tree 95: 0.0
# Distance between tree 95 and tree 96: 0.0
# Distance between tree 96 and tree 97: 0.0
# Distance between tree 97 and tree 98: 0.0
# Distance between tree 98 and tree 99: 0.0
# Distance between tree 99 and tree 100: 0.0
# Distance between tree 100 and tree 101: 0.0
# Distance between tree 101 and tree 102: 0.0
# Distance between tree 102 and tree 103: 0.0
# Distance between tree 103 and tree 104: 0.0
# Distance between tree 104 and tree 105: 0.0
# Distance between tree 105 and tree 106: 0.0
# Distance between tree 106 and tree 107: 0.0
# Distance between tree 107 and tree 108: 0.0
# Distance between tree 108 and tree 109: 0.0
# Distance between tree 109 and tree 110: 0.0
# Distance between tree 110 and tree 111: 0.0
# Distance between tree 111 and tree 112: 0.0
# Distance between tree 112 and tree 113: 0.0
# Distance between tree 113 and tree 114: 0.0
# Distance between tree 114 and tree 115: 0.0
# Distance between tree 115 and tree 116: 0.0
# Distance between tree 116 and tree 117: 0.0
# Distance between tree 117 and tree 118: 0.43636363636363634
# Distance between tree 118 and tree 119: 0.0
# Distance between tree 119 and tree 120: 0.0
# Distance between tree 120 and tree 121: 0.0
# ...
# Distance between tree 133 and tree 134: 0.0
# Distance between tree 134 and tree 135: 0.0
# Distance between tree 135 and tree 136: 0.03636363636363636
# Distance between tree 136 and tree 137: 0.03636363636363636
# Distance between tree 137 and tree 138: 0.0
# Distance between tree 138 and tree 139: 0.0
# Distance between tree 139 and tree 140: 0.0
# Distance between tree 140 and tree 141: 0.0
# Distance between tree 141 and tree 142: 0.0
# Distance between tree 142 and tree 143: 0.0
# Distance between tree 143 and tree 144: 0.0
# Distance between tree 144 and tree 145: 0.0
# Distance between tree 145 and tree 146: 0.0
# Distance between tree 146 and tree 147: 0.0
# Distance between tree 147 and tree 148: 0.0
# Distance between tree 148 and tree 149: 0.0
# Distance between tree 149 and tree 150: 0.0
# Distance between tree 150 and tree 151: 0.0
# Distance between tree 151 and tree 152: 0.0
# Distance between tree 152 and tree 153: 0.0
# Distance between tree 153 and tree 154: 0.0
# Distance between tree 154 and tree 155: 0.0
# Distance between tree 155 and tree 156: 0.0
# Distance between tree 156 and tree 157: 0.0
# Distance between tree 157 and tree 158: 0.0
# Distance between tree 158 and tree 159: 0.0
# Distance between tree 159 and tree 160: 0.0
# Distance between tree 160 and tree 161: 0.0
# Distance between tree 161 and tree 162: 0.0
# Distance between tree 162 and tree 163: 0.0
# Distance between tree 163 and tree 164: 0.0
# Distance between tree 164 and tree 165: 0.0
# Distance between tree 165 and tree 166: 0.0
# Distance between tree 166 and tree 167: 0.0
# Distance between tree 167 and tree 168: 0.0
# Distance between tree 168 and tree 169: 0.0
# Distance between tree 169 and tree 170: 0.0
# Distance between tree 170 and tree 171: 0.0
# Distance between tree 171 and tree 172: 0.0
# Distance between tree 172 and tree 173: 0.0
# Distance between tree 173 and tree 174: 0.0
# Distance between tree 174 and tree 175: 0.0
# Distance between tree 175 and tree 176: 0.0
# Distance between tree 176 and tree 177: 0.0
# Distance between tree 177 and tree 178: 0.43636363636363634
# Distance between tree 178 and tree 179: 0.14545454545454545
# Distance between tree 179 and tree 180: 0.0
# Distance between tree 180 and tree 181: 0.0
# Distance between tree 181 and tree 182: 0.0
# Distance between tree 182 and tree 183: 0.0
# Distance between tree 183 and tree 184: 0.0
# Distance between tree 184 and tree 185: 0.0
# Distance between tree 185 and tree 186: 0.0
# Distance between tree 186 and tree 187: 0.0
# Distance between tree 187 and tree 188: 0.0
# Distance between tree 188 and tree 189: 0.0
# Distance between tree 189 and tree 190: 0.0
# Distance between tree 190 and tree 191: 0.0
# Distance between tree 191 and tree 192: 0.0
# Distance between tree 192 and tree 193: 0.0
# Distance between tree 193 and tree 194: 0.0
# Distance between tree 194 and tree 195: 0.0
# Distance between tree 195 and tree 196: 0.0
# Distance between tree 196 and tree 197: 0.0
# Distance between tree 197 and tree 198: 0.0
# Distance between tree 198 and tree 199: 0.0
# Distance between tree 199 and tree 200: 0.0
# Distance between tree 200 and tree 201: 0.0
# Distance between tree 201 and tree 202: 0.0
# Distance between tree 202 and tree 203: 0.0
# Distance between tree 203 and tree 204: 0.0
# Distance between tree 204 and tree 205: 0.0
# Distance between tree 205 and tree 206: 0.0
# Distance between tree 206 and tree 207: 0.0
# Distance between tree 207 and tree 208: 0.0
# Distance between tree 208 and tree 209: 0.0
# Distance between tree 209 and tree 210: 0.0
# Distance between tree 210 and tree 211: 0.0
# Distance between tree 211 and tree 212: 0.0
# Distance between tree 212 and tree 213: 0.0
# Distance between tree 213 and tree 214: 0.0
# Distance between tree 214 and tree 215: 0.0
# Distance between tree 215 and tree 216: 0.0
# Distance between tree 216 and tree 217: 0.0
# Distance between tree 217 and tree 218: 0.0
# Distance between tree 218 and tree 219: 0.0
# Distance between tree 219 and tree 220: 0.0
# Distance between tree 220 and tree 221: 0.0
# Distance between tree 221 and tree 222: 0.0
# Distance between tree 222 and tree 223: 0.0
# Distance between tree 223 and tree 224: 0.0
# Distance between tree 224 and tree 225: 0.0
# Distance between tree 225 and tree 226: 0.0
# Distance between tree 226 and tree 227: 0.0
# Distance between tree 227 and tree 228: 0.0
# Distance between tree 228 and tree 229: 0.0
# Distance between tree 229 and tree 230: 0.0
# Distance between tree 230 and tree 231: 0.0
# Distance between tree 231 and tree 232: 0.0
# Distance between tree 232 and tree 233: 0.0
# Distance between tree 233 and tree 234: 0.0
# Distance between tree 234 and tree 235: 0.07272727272727272
# Distance between tree 235 and tree 236: 0.07272727272727272
# Distance between tree 236 and tree 237: 0.0
# Distance between tree 237 and tree 238: 0.0
# Distance between tree 238 and tree 239: 0.0
# Distance between tree 239 and tree 240: 0.0
# Distance between tree 240 and tree 241: 0.0
# Distance between tree 241 and tree 242: 0.07272727272727272
# Loaded 243 trees.
# Computed majority consensus tree with threshold 0.99.
# Generated 4 permutations.
#
# Best permutation found with average distance 0.25559729526671704:
# ['C1', 'C2', 'D1', 'X', 'D2', 'A1', 'A2', 'B2', 'B1', 'O2', 'O1']
#
# Circular distances between consecutive trees after optimization:
# Distance between tree 0 and tree 1: 0.0
# Distance between tree 1 and tree 2: 0.0
# Distance between tree 2 and tree 3: 0.0
# Distance between tree 3 and tree 4: 0.0
# Distance between tree 4 and tree 5: 0.0
# Distance between tree 5 and tree 6: 0.0
# Distance between tree 6 and tree 7: 0.0
# Distance between tree 7 and tree 8: 0.0
# Distance between tree 8 and tree 9: 0.0
# Distance between tree 9 and tree 10: 0.0
# Distance between tree 10 and tree 11: 0.0
# Distance between tree 11 and tree 12: 0.0
# Distance between tree 12 and tree 13: 0.0
# Distance between tree 13 and tree 14: 0.0
# Distance between tree 14 and tree 15: 0.0
# Distance between tree 15 and tree 16: 0.0
# Distance between tree 16 and tree 17: 0.0
# Distance between tree 17 and tree 18: 0.0
# Distance between tree 18 and tree 19: 0.0
# Distance between tree 19 and tree 20: 0.0
# Distance between tree 20 and tree 21: 0.0
# Distance between tree 21 and tree 22: 0.0
# Distance between tree 22 and tree 23: 0.0
# Distance between tree 23 and tree 24: 0.0
# Distance between tree 24 and tree 25: 0.0
# Distance between tree 25 and tree 26: 0.0
# Distance between tree 26 and tree 27: 0.0
# Distance between tree 27 and tree 28: 0.0
# Distance between tree 28 and tree 29: 0.0
# Distance between tree 29 and tree 30: 0.0
# Distance between tree 30 and tree 31: 0.0
# Distance between tree 31 and tree 32: 0.0
# Distance between tree 32 and tree 33: 0.0
# Distance between tree 33 and tree 34: 0.0
# Distance between tree 34 and tree 35: 0.0
# Distance between tree 35 and tree 36: 0.0
# Distance between tree 36 and tree 37: 0.0
# Distance between tree 37 and tree 38: 0.0
# Distance between tree 38 and tree 39: 0.0
# Distance between tree 39 and tree 40: 0.0
# Distance between tree 40 and tree 41: 0.0
# Distance between tree 41 and tree 42: 0.0
# Distance between tree 42 and tree 43: 0.0
# Distance between tree 43 and tree 44: 0.0
# Distance between tree 44 and tree 45: 0.0
# Distance between tree 45 and tree 46: 0.0
# Distance between tree 46 and tree 47: 0.07272727272727272
# Distance between tree 47 and tree 48: 0.0
# Distance between tree 48 and tree 49: 0.07272727272727272
# Distance between tree 49 and tree 50: 0.0
# Distance between tree 50 and tree 51: 0.0
# Distance between tree 51 and tree 52: 0.0
# Distance between tree 52 and tree 53: 0.0
# Distance between tree 53 and tree 54: 0.0
# Distance between tree 54 and tree 55: 0.03636363636363636
# Distance between tree 55 and tree 56: 0.0
# Distance between tree 56 and tree 57: 0.07272727272727272
# Distance between tree 57 and tree 58: 0.0
# Distance between tree 58 and tree 59: 0.0
# Distance between tree 59 and tree 60: 0.0
# Distance between tree 60 and tree 61: 0.0
# Distance between tree 61 and tree 62: 0.0
# Distance between tree 62 and tree 63: 0.0
# Distance between tree 63 and tree 64: 0.0
# Distance between tree 64 and tree 65: 0.0
# Distance between tree 65 and tree 66: 0.0
# Distance between tree 66 and tree 67: 0.0
# Distance between tree 67 and tree 68: 0.0
# Distance between tree 68 and tree 69: 0.0
# Distance between tree 69 and tree 70: 0.0
# Distance between tree 70 and tree 71: 0.0
# Distance between tree 71 and tree 72: 0.0
# Distance between tree 72 and tree 73: 0.0
# Distance between tree 73 and tree 74: 0.0
# Distance between tree 74 and tree 75: 0.0
# Distance between tree 75 and tree 76: 0.0
# Distance between tree 76 and tree 77: 0.0
# Distance between tree 77 and tree 78: 0.0
# Distance between tree 78 and tree 79: 0.0
# Distance between tree 79 and tree 80: 0.0
# Distance between tree 80 and tree 81: 0.0
# Distance between tree 81 and tree 82: 0.0
# Distance between tree 82 and tree 83: 0.0
# Distance between tree 83 and tree 84: 0.0
# Distance between tree 84 and tree 85: 0.0
# Distance between tree 85 and tree 86: 0.0
# Distance between tree 86 and tree 87: 0.0
# Distance between tree 87 and tree 88: 0.0
# Distance between tree 88 and tree 89: 0.07272727272727272
# Distance between tree 89 and tree 90: 0.0
# Distance between tree 90 and tree 91: 0.0
# Distance between tree 91 and tree 92: 0.0
# Distance between tree 92 and tree 93: 0.07272727272727272
# Distance between tree 93 and tree 94: 0.0
# Distance between tree 94 and tree 95: 0.0
# Distance between tree 95 and tree 96: 0.0
# Distance between tree 96 and tree 97: 0.0
# Distance between tree 97 and tree 98: 0.0
# Distance between tree 98 and tree 99: 0.0
# Distance between tree 99 and tree 100: 0.0
# Distance between tree 100 and tree 101: 0.0
# Distance between tree 101 and tree 102: 0.0
# Distance between tree 102 and tree 103: 0.0
# Distance between tree 103 and tree 104: 0.0
# Distance between tree 104 and tree 105: 0.0
# Distance between tree 105 and tree 106: 0.0
# Distance between tree 106 and tree 107: 0.0
# Distance between tree 107 and tree 108: 0.0
# Distance between tree 108 and tree 109: 0.0
# Distance between tree 109 and tree 110: 0.0
# Distance between tree 110 and tree 111: 0.0
# Distance between tree 111 and tree 112: 0.0
# Distance between tree 112 and tree 113: 0.0
# Distance between tree 113 and tree 114: 0.0
# Distance between tree 114 and tree 115: 0.0
# Distance between tree 115 and tree 116: 0.0
# Distance between tree 116 and tree 117: 0.0
# Distance between tree 117 and tree 118: 0.21818181818181817
# Distance between tree 118 and tree 119: 0.0
# Distance between tree 119 and tree 120: 0.0
# Distance between tree 120 and tree 121: 0.0
# Distance between tree 121 and tree 122: 0.0
# Distance between tree 122 and tree 123: 0.0
# Distance between tree 123 and tree 124: 0.0
# Distance between tree 124 and tree 125: 0.0
# Distance between tree 125 and tree 126: 0.0
# Distance between tree 126 and tree 127: 0.0
# Distance between tree 127 and tree 128: 0.0
# Distance between tree 128 and tree 129: 0.07272727272727272
# Distance between tree 129 and tree 130: 0.0
# Distance between tree 130 and tree 131: 0.0
# Distance between tree 131 and tree 132: 0.0
# Distance between tree 132 and tree 133: 0.0
# Distance between tree 133 and tree 134: 0.0
# Distance between tree 134 and tree 135: 0.0
# Distance between tree 135 and tree 136: 0.03636363636363636
# Distance between tree 136 and tree 137: 0.03636363636363636
# Distance between tree 137 and tree 138: 0.0
# Distance between tree 138 and tree 139: 0.0
# Distance between tree 139 and tree 140: 0.0
# Distance between tree 140 and tree 141: 0.0
# Distance between tree 141 and tree 142: 0.0
# Distance between tree 142 and tree 143: 0.0
# Distance between tree 143 and tree 144: 0.0
# Distance between tree 144 and tree 145: 0.0
# Distance between tree 145 and tree 146: 0.0
# Distance between tree 146 and tree 147: 0.0
# Distance between tree 147 and tree 148: 0.0
# Distance between tree 148 and tree 149: 0.0
# Distance between tree 149 and tree 150: 0.0
# Distance between tree 150 and tree 151: 0.0
# Distance between tree 151 and tree 152: 0.0
# Distance between tree 152 and tree 153: 0.0
# Distance between tree 153 and tree 154: 0.0
# Distance between tree 154 and tree 155: 0.0
# Distance between tree 155 and tree 156: 0.0
# Distance between tree 156 and tree 157: 0.0
# Distance between tree 157 and tree 158: 0.0
# Distance between tree 158 and tree 159: 0.0
# Distance between tree 159 and tree 160: 0.0
# Distance between tree 160 and tree 161: 0.0
# Distance between tree 161 and tree 162: 0.0
# Distance between tree 162 and tree 163: 0.0
# Distance between tree 163 and tree 164: 0.0
# Distance between tree 164 and tree 165: 0.0
# Distance between tree 165 and tree 166: 0.0
# Distance between tree 166 and tree 167: 0.0
# Distance between tree 167 and tree 168: 0.0
# Distance between tree 168 and tree 169: 0.0
# Distance between tree 169 and tree 170: 0.0
# Distance between tree 170 and tree 171: 0.0
# Distance between tree 171 and tree 172: 0.0
# Distance between tree 172 and tree 173: 0.0
# Distance between tree 173 and tree 174: 0.0
# Distance between tree 174 and tree 175: 0.0
# Distance between tree 175 and tree 176: 0.0
# Distance between tree 176 and tree 177: 0.0
# Distance between tree 177 and tree 178: 0.07272727272727272
# Distance between tree 178 and tree 179: 0.0
# Distance between tree 179 and tree 180: 0.0
# Distance between tree 180 and tree 181: 0.0
# Distance between tree 181 and tree 182: 0.0
# Distance between tree 182 and tree 183: 0.0
# Distance between tree 183 and tree 184: 0.0
# Distance between tree 184 and tree 185: 0.0
# Distance between tree 185 and tree 186: 0.0
# Distance between tree 186 and tree 187: 0.0
# Distance between tree 187 and tree 188: 0.0
# Distance between tree 188 and tree 189: 0.0
# Distance between tree 189 and tree 190: 0.0
# Distance between tree 190 and tree 191: 0.0
# Distance between tree 191 and tree 192: 0.0
# Distance between tree 192 and tree 193: 0.0
# Distance between tree 193 and tree 194: 0.0
# Distance between tree 194 and tree 195: 0.0
# Distance between tree 195 and tree 196: 0.0
# Distance between tree 196 and tree 197: 0.0
# Distance between tree 197 and tree 198: 0.0
# Distance between tree 198 and tree 199: 0.0
# Distance between tree 199 and tree 200: 0.0
# Distance between tree 200 and tree 201: 0.0
# Distance between tree 201 and tree 202: 0.0
# Distance between tree 202 and tree 203: 0.0
# Distance between tree 203 and tree 204: 0.0
# Distance between tree 204 and tree 205: 0.0
# Distance between tree 205 and tree 206: 0.0
# Distance between tree 206 and tree 207: 0.0
# Distance between tree 207 and tree 208: 0.0
# Distance between tree 208 and tree 209: 0.0
# Distance between tree 209 and tree 210: 0.0
# Distance between tree 210 and tree 211: 0.0
# Distance between tree 211 and tree 212: 0.0
# Distance between tree 212 and tree 213: 0.0
# Distance between tree 213 and tree 214: 0.0
# Distance between tree 214 and tree 215: 0.0
# Distance between tree 215 and tree 216: 0.0
# Distance between tree 216 and tree 217: 0.0
# Distance between tree 217 and tree 218: 0.0
# Distance between tree 218 and tree 219: 0.0
# Distance between tree 219 and tree 220: 0.0
# Distance between tree 220 and tree 221: 0.0
# Distance between tree 221 and tree 222: 0.0
# Distance between tree 222 and tree 223: 0.0
# Distance between tree 223 and tree 224: 0.0
# Distance between tree 224 and tree 225: 0.0
# Distance between tree 225 and tree 226: 0.0
# Distance between tree 226 and tree 227: 0.0
# Distance between tree 227 and tree 228: 0.0
# Distance between tree 228 and tree 229: 0.0
# Distance between tree 229 and tree 230: 0.0
# Distance between tree 230 and tree 231: 0.0
# Distance between tree 231 and tree 232: 0.0
# Distance between tree 232 and tree 233: 0.0
# Distance between tree 233 and tree 234: 0.0
# Distance between tree 234 and tree 235: 0.07272727272727272
# Distance between tree 235 and tree 236: 0.07272727272727272
# Distance between tree 236 and tree 237: 0.0
# Distance between tree 237 and tree 238: 0.0
# Distance between tree 238 and tree 239: 0.0
# Distance between tree 239 and tree 240: 0.0
# Distance between tree 240 and tree 241: 0.03636363636363636
# Distance between tree 241 and tree 242: 0.07272727272727272
#
# Average circular distance over the trajectory after optimization: 0.004507888805409467
